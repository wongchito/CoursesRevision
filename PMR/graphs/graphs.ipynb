# %%
# %load_ext tikzmagic

# %%
# %%tikz -f svg -S DAG_serial.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (z) at (0, 0) {$z$};
# \node (x) at +(-1.5, 0) {$x$};
# \node (y) at +(1.5, 0) {$y$};
# \edge {x} {z};
# \edge {z} {y};

# %%
# %%tikz -f svg -S DAG_diverging.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (z) at (0, 0) {$z$};
# \node (x) at +(-1.5, 0) {$x$};
# \node (y) at +(1.5, 0) {$y$};
# \edge {z} {x,y};

# %%
# %%tikz -f svg -S DAG_converging.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (z) at (0, 0) {$z$};
# \node (x) at +(-1.5, 0) {$x$};
# \node (y) at +(1.5, 0) {$y$};
# \edge {x,y} {z};

# %%
# %%tikz -f svg -S DAG_dsep_block1.svg
# \usetikzlibrary{bayesnet}
# \node[obs] (z) at (0, 0) {$z$};
# \node[latent] (x) at +(-1.5, 0) {$x$};
# \node[latent] (y) at +(1.5, 0) {$y$};
# \edge {x} {z};
# \edge {z} {y};

# %%
# %%tikz -f svg -S DAG_dsep_block2.svg
# \usetikzlibrary{bayesnet}
# \node[obs] (z) at (0, 0) {$z$};
# \node[latent] (x) at +(-1.5, 0) {$x$};
# \node[latent] (y) at +(1.5, 0) {$y$};
# \edge {z} {x,y};

# %%
# %%tikz -f svg -S DAG_dsep_block3.svg
# \usetikzlibrary{bayesnet}
# \node[latent] (z) at (0, 0) {$z$};
# \node[latent] (x) at +(-1.5, 0) {$x$};
# \node[latent] (y) at +(1.5, 0) {$y$};
# \node[latent] (z_desc) at +(0,-1.5) {};
# \edge {x,y} {z};
# \edge {z} {z_desc};

# %%
# %%tikz -f svg -S DAG_dsep_notblock3.svg
# \usetikzlibrary{bayesnet}
# \node[latent] (z) at (0, 0) {$z$};
# \node[latent] (x) at +(-1.5, 0) {$x$};
# \node[latent] (y) at +(1.5, 0) {$y$};
# \node[obs] (z_desc) at +(0,-1.5) {};
# \edge {x,y} {z};
# \edge {z} {z_desc};

# %%
# %%tikz -f svg -S MinImap_undir.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x1) at (0, 0) {$x_1$};
# \node (x2) at +(1.5, 0) {$x_2$};
# \node (x3) at +(3, 0) {$x_3$};
# \node (x4) at +(4.5, 0) {$x_4$};
# \edge[-] {x1} {x2};
# \edge[-] {x2} {x3};

# %%
# %%tikz -f svg -S NotImap_undir.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x1) at (0, 0) {$x_1$};
# \node (x2) at +(1.5, 0) {$x_2$};
# \node (x3) at +(3, 0) {$x_3$};
# \node (x4) at +(4.5, 0) {$x_4$};
# \edge[-] {x2} {x3};

# %%
# %%tikz -f svg -S NotMinImap_undir.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x1) at (0, 0) {$x_1$};
# \node (x2) at +(1.5, 0) {$x_2$};
# \node (x3) at +(3, 0) {$x_3$};
# \node (x4) at +(4.5, 0) {$x_4$};
# \edge[-] {x1} {x2};
# \edge[-] {x2} {x3};
# \draw [-] (x1) to [out=-45,in=-135] (x3);

# %%
# %%tikz -f svg -S FG_UG.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x1) at (0, 0) {$x_1$};
# \node (x2) at +(-45:2) {$x_2$};
# \node (x3) at +(-135:2) {$x_3$};
#
# \edge[-] {x1} {x2};
# \edge[-] {x1} {x3};
# \edge[-] {x3} {x2};

# %%
# %%tikz -f svg -S FG_pA.svg
# \usetikzlibrary{bayesnet, calc}
# \tikzstyle{every node} = [latent]
# \node (x1) at (0, 0) {$x_1$};
# \node (x2) at +(-45:2) {$x_2$};
# \node (x3) at +(-135:2) {$x_3$};
#
# \node[factor, label=right:{$\phi_1$}] (phi1) at +(-45:1) {};
# \node[factor, label=above:{$\phi_2$}] (phi2) at ($(x1) + (0,-{sqrt(2)})$) {};
# \node[factor, label=left:{$\phi_3$}] (phi3) at +(-135:1) {};
#
# \factoredge {x1, x2} {phi1} {};
# \factoredge {x3, x2} {phi2} {};
# \factoredge {x1, x3} {phi3} {};

# %%
# %%tikz -f svg -S FG_pB.svg
# \usetikzlibrary{bayesnet, calc}
# \tikzstyle{every node} = [latent]
# \node (x1) at (0, 0) {$x_1$};
# \node (x2) at +(-45:2) {$x_2$};
# \node (x3) at +(-135:2) {$x_3$};
#
# \node[factor, label=45:{$\phi$}] (phi) at ($(x1) + (0,-{sqrt(2)})$) {};
#
# \factoredge {x1, x2, x3} {phi} {};

# %%
# %%tikz -f svg -S FG_mix_DG1.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x3) at (0, 0) {$x_3$};
# \node (x2) at +(45:2) {$x_2$};
# \node (x1) at +(135:2) {$x_1$};
#
# \edge {x1} {x2, x3};
# \edge {x2} {x3};

# %%
# %%tikz -f svg -S FG_mix_DG2.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x3) at (0, 0) {$x_3$};
# \node (x2) at +(45:2) {$x_2$};
# \node (x1) at +(135:2) {$x_1$};
#
# \edge {x1} {x3};
# \edge {x2} {x1, x3};

# %%
# %%tikz -f svg -S FG_mix_UG.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x3) at (0, 0) {$x_3$};
# \node (x2) at +(45:2) {$x_2$};
# \node (x1) at +(135:2) {$x_1$};
#
# \edge[-] {x1} {x3};
# \edge[-] {x2} {x1, x3};

# %%
# %%tikz -f svg -S FG_mix_FG.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (x3) at (0, -1) {$x_3$};
# \node (x2) at +(45:2) {$x_2$};
# \node (x1) at +(135:2) {$x_1$};
#
# \node[factor, label=right:{$p(x_3|x_1, x_2)$}] (pcond) at (0,0.5) {};
# \node[factor, label=above:{$p(x_1, x_2)$}] (p) at (0, {sqrt(2)}) {};
#
# \factoredge {p} {x1, x2} {};
# \factoredge {x1, x2} {pcond} {x3};

# %%
# %%tikz -f svg -S EI_chain_before.svg
# \usetikzlibrary{bayesnet}
# \node[latent] (x1) at (0, 0) {$x_1$};
# \node[latent] (x2) at (2, 0) {$x_2$};
# \node (xi) at (4, 0) {$\cdots$};
# \node[latent] (xd) at (6, 0) {$x_d$};
#
# \node[factor, label=above:{$\phi_1$}] (phi1) at (1,0) {};
# \node[factor, label=above:{$\phi_2$}] (phi2) at (3,0) {};
# \node[factor, label=above:{$\phi_{d-1}$}] (phid1) at (5,0) {};
# \node[factor, label=above:{$\phi_d$}] (phid) at (7,0) {};
#
# \factoredge {phi1} {x1, x2} {};
# \factoredge {phi2} {xi, x2} {};
# \factoredge {phid1} {xi, xd} {};
# \factoredge {phid} {xd} {};

# %%
# %%tikz -f svg -S EI_chain_1.svg
# \usetikzlibrary{bayesnet}
# \node[latent] (x1) at (0, 0) {$x_1$};
# \node[latent] (x2) at (2, 0) {$x_2$};
# \node (xi) at (3, 0) {$\cdots$};
# \node[latent] (xd1) at (4, 0) {$x_{d-1}$};
#
# \node[factor, label=above:{$\phi_1$}] (phi1) at (1,0) {};
# \node[factor, label=above:{$\tilde\phi_d$}] (tildephid) at (5,0) {};
#
# \edge[-] {x2, xd1} {xi};
#
# \factoredge {phi1} {x1, x2} {};
# \factoredge {tildephid} {xd1} {};

# %%
# %%tikz -f svg -S EI_chain_2.svg
# \usetikzlibrary{bayesnet}
# \node[latent] (x1) at (0, 0) {$x_1$};
# \node[latent] (x2) at (2, 0) {$x_2$};
# \node (xi) at (3, 0) {$\cdots$};
# \node[latent] (xd2) at (4, 0) {$x_{d-2}$};
#
# \node[factor, label=above:{$\phi_1$}] (phi1) at (1,0) {};
# \node[factor, label=above:{$\tilde\phi_{d,d-1}$}] (tildephid) at (5,0) {};
#
# \edge[-] {x2, xd2} {xi};
#
# \factoredge {phi1} {x1, x2} {};
# \factoredge {tildephid} {xd2} {};

# %%
# %%tikz -f svg -S EI_sumprod_f2v.svg
# \usetikzlibrary{bayesnet, calc}
# \node[latent] (x1) at (0, 0) {$x_1$};
# \node[latent] (x2) at (0, -1.5) {$x_2$};
# \node[factor, label=45:{$\phi$}] (phi) at (1.5,-0.75) {};
# \node[latent] (x) at ($(phi)+(1.5,0)$) {$x$};
#
# \draw[-] (x1) -- (phi) node[midway, above, sloped, style={text=red, font=\scriptsize}] {$\mu_{x_1\to\phi}$};
# \draw[-] (x2) -- (phi) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{x_2\to\phi}$};
# \draw[-] (phi) -- (x) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{\phi\to x}$};

# %%
# %%tikz -f svg -S EI_sumprod_v2f.svg
# \usetikzlibrary{bayesnet, calc}
# \node[factor, label=left:{$\phi_1$}] (phi1) at (0, 0) {};
# \node[factor, label=left:{$\phi_2$}] (phi2) at (0, -1.5) {};
# \node[latent] (x) at (1.5,-0.75) {$x$};
# \node[factor, label=above:{$\phi$}] (phi) at ($(x)+(1.5,0)$) {};
#
# \draw[-] (phi1) -- (x) node[midway, above, sloped, style={text=red, font=\scriptsize}] {$\mu_{\phi_1\to x}$};
# \draw[-] (phi2) -- (x) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{\phi_2\to x}$};
# \draw[-] (x) -- (phi) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{x\to\phi}$};

# %%
# %%tikz -f svg -S EI_sumprod_uni.svg
# \usetikzlibrary{bayesnet, calc}
# \node[factor, label=left:{$\phi_1$}] (phi1) at (0, 0) {};
# \node[factor, label=left:{$\phi_2$}] (phi2) at (0, -1.5) {};
# \node[latent] (x) at (1.5,-0.75) {$x$};
# \node[factor, label=above:{$\phi_3$}] (phi3) at ($(x)+(1.5,0)$) {};
#
# \draw[-] (phi1) -- (x) node[midway, above, sloped, style={text=red, font=\scriptsize}] {$\mu_{\phi_1\to x}$};
# \draw[-] (phi2) -- (x) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{\phi_2\to x}$};
# \draw[-] (phi3) -- (x) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{\phi_3\to x}$};

# %%
# %%tikz -f svg -S EI_sumprod_joint.svg
# \usetikzlibrary{bayesnet, calc}
# \node[latent] (x1) at (0, 0) {$x_1$};
# \node[latent] (x2) at (0, -1.5) {$x_2$};
# \node[factor, label=45:{$\phi$}] (phi) at (1.5,-0.75) {};
# \node[latent] (x3) at ($(phi)+(1.5,0)$) {$x_3$};
#
# \draw[-] (x1) -- (phi) node[midway, above, sloped, style={text=red, font=\scriptsize}] {$\mu_{x_1\to\phi}$};
# \draw[-] (x2) -- (phi) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{x_2\to\phi}$};
# \draw[-] (x3) -- (phi) node[midway, below, sloped, style={text=red, font=\scriptsize}] {$\mu_{x_3\to\phi}$};

# %%
# %%tikz -f svg -S HMM_DAG.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (h1) at (0, 0) {$h_1$};
# \node (h2) at (1.5,0) {$h_2$};
# \node (h3) at (3,0) {$h_3$};
# \node (h4) at (4.5,0) {$h_4$};
#
# \node (v1) at (0,-1.5) {$v_1$};
# \node (v2) at (1.5,-1.5) {$v_2$};
# \node (v3) at (3,-1.5) {$v_3$};
# \node (v4) at (4.5,-1.5) {$v_4$};
#
# \edge {h1} {h2, v1};
# \edge {h2} {h3, v2};
# \edge {h3} {h4, v3};
# \edge {h4} {v4}

# %%
# %%tikz -f svg -S HMM_FG.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (h1) at (0, 0) {$h_1$};
# \node (h2) at (2,0) {$h_2$};
# \node (h3) at (4,0) {$h_3$};
# \node (h4) at (6,0) {$h_4$};
#
# \node (v1) at (0,-2) {$v_1$};
# \node (v2) at (2,-2) {$v_2$};
# \node (v3) at (4,-2) {$v_3$};
# \node (v4) at (6,-2) {$v_4$};
#
# \node[factor, label=left:{$p(h_1)$}] (p1) at (-1,0) {};
# \node[factor, label=above:{$p(h_2|h_1)$}] (p21) at (1,0) {};
# \node[factor, label=above:{$p(h_3|h_2)$}] (p32) at (3,0) {};
# \node[factor, label=above:{$p(h_4|h_3)$}] (p43) at (5,0) {};
# \node[factor, label=left:{$p(v_1|h_1)$}] (p11) at (0,-1) {};
# \node[factor, label=left:{$p(v_2|h_2)$}] (p22) at (2,-1) {};
# \node[factor, label=left:{$p(v_3|h_3)$}] (p33) at (4,-1) {};
# \node[factor, label=left:{$p(v_4|h_4)$}] (p44) at (6,-1) {};
#
# \factoredge {p1} {h1} {};
# \factoredge {p21} {h1, h2} {};
# \factoredge {p32} {h3, h2} {};
# \factoredge {p43} {h3, h4} {};
# \factoredge {p11} {h1, v1} {};
# \factoredge {p22} {h2, v2} {};
# \factoredge {p33} {h3, v3} {};
# \factoredge {p44} {h4, v4} {};

# %%
# %%tikz -f svg -S FA_ICA.svg
# \usetikzlibrary{bayesnet}
# \tikzstyle{every node} = [latent]
# \node (h1) at (0, 0) {$h_1$};
# \node (h2) at (1.5,0) {$h_2$};
# \node (h3) at (3,0) {$h_3$};
#
# \node (v1) at (-1.5,-2) {$v_1$};
# \node (v2) at (0,-2) {$v_2$};
# \node (v3) at (1.5,-2) {$v_3$};
# \node (v4) at (3,-2) {$v_4$};
# \node (v5) at (4.5,-2) {$v_5$};
#
# \edge {h1} {v1, v2, v3, v4, v5};
# \edge {h2} {v1, v2, v3, v4, v5};
# \edge {h3} {v1, v2, v3, v4, v5};
